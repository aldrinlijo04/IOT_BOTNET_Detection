# %%
import tensorflow as tf
import pandas as pd
import seaborn as sn
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\SEC\Desktop\GIT HUB\BOLT\IOT_BOTNET_Detection\IOT_BOTNET_Detection\dataset\ACI-IoT-2023.csv")

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
# ...

# %%
df.describe()
# Out:
# c:\Users\SEC\Desktop\GIT HUB\BOLT\IOT_BOTNET_Detection\IOT_BOTNET_Detection\bolt\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\SEC\Desktop\GIT HUB\BOLT\IOT_BOTNET_Detection\IOT_BOTNET_Detection\bolt\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#            Src Port      Dst Port      Protocol  Flow Duration  \
# count  1.231411e+06  1.231411e+06  1.231411e+06   1.231411e+06
# mean   3.680030e+04  1.540297e+04  6.433792e+00   5.236489e+06
# std    2.331748e+04  2.044498e+04  4.919235e+00   1.188271e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.353000e+03  5.300000e+01  6.000000e+00   3.357000e+03
# 50%    4.814600e+04  3.017000e+03  6.000000e+00   6.631000e+03
# 75%    5.529500e+04  3.096650e+04  6.000000e+00   3.117183e+06
# ...
